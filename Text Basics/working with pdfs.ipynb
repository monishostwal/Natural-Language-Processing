# %%
import PyPDF2

# %%
myfile=open('./Business_Proposal.pdf',mode='rb')#rb stands for read in binary

# %%
myfile.read()
# Out:
# b'%PDF-1.7\r\n%\xb5\xb5\xb5\xb5\r\n1 0 obj\r\n<</Type/Catalog/Pages 2 0 R/Lang(en-US) /StructTreeRoot 16 0 R/MarkInfo<</Marked true>>/Metadata 42 0 R/ViewerPreferences 43 0 R>>\r\nendobj\r\n2 0 obj\r\n<</Type/Pages/Count 2/Kids[ 3 0 R 13 0 R] >>\r\nendobj\r\n3 0 obj\r\n<</Type/Page/Parent 2 0 R/Resources<</Font<</F1 5 0 R/F2 9 0 R/F3 11 0 R>>/ExtGState<</GS7 7 0 R/GS8 8 0 R>>/ProcSet[/PDF/Text/ImageB/ImageC/ImageI] >>/MediaBox[ 0 0 612 792] /Contents 4 0 R/Group<</Type/Group/S/Transparency/CS/DeviceRGB>>/Tabs/S/StructParents 0>>\r\nendobj\r\n4 0 obj\r\n<</Filter/FlateDecode/Length 2658>>\r\nstream\r\nx\x9c\xbdZm\x8f\xdb6\x12\xfe\xbe\xc0\xfe\x07}\xb4\x0f]F\x94\xa87\xa0(p\xd9\xe4\x8a\\\xaf\x974\xdd\xe2\x0e(\xee\x03\xd7\xa2m!Z\xc9\'[\xd9K\x7f\xfd\xcd\x0cEJ\xf6\xae\xcc$\xa5\x93\x0f\x8eW\xa6\xc4\xd13o\xcf\xcc0x\xf1.\xf8\xfe\xfb\x17?\xdf\xbey\x15\x84?\xfc\x10\xbc|u\x1b\xfc\xf7\xfa*d!\xfe+x\x14\x84A\n\x9fY\x11\x05\x9d\xba\xbe\xfa\xd7_\x82\xe6\xfa\xea\xe5\xdd\xf5\xd5\x8b\xbf\xf1 \x8eX(\x82\x
# ...

# %%
pdf_reader=PyPDF2.PdfFileReader(myfile)

# %%
pdf_reader.numPages
# Out:
# 2

# %%
page_one=pdf_reader.getPage(1)

# %%
print(page_one.extractText())
# Out:
# AUTHORS:
#
# Amy Baker, Finance Chair, x345, abaker@ourcompany.com
#
# Chris Donaldson, Accounting Dir., x621, cdonaldson@ourcompany.com
#
# Erin Freeman, Sr. VP, x879, efreeman@ourcompany.com

# %%
myfile.close()
